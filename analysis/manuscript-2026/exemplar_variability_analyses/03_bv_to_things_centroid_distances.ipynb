# %% [markdown]
# # BV exemplar distance to THINGS category centroid
#
# **Purpose:** For each category we have a THINGS centroid (mean of THINGS exemplar embeddings). For each BV exemplar we compute the L2 distance to the THINGS centroid (and optionally to the BV centroid for comparison).
#
# **Outputs:**
# 1. **Per-category summary CSV:** mean/std of BV-to-THINGS-centroid distance, mean BV-to-BV-centroid, correlation, n_bv, n_things.
# 2. **Per-exemplar CSV (optional):** category, subject_id, age_mo, dist_to_things_centroid, dist_to_bv_centroid.
# 3. **t-SNE plot** for one or all categories: BV exemplars, THINGS exemplars, THINGS centroid; BV points colored by distance to THINGS centroid (far = potential false alarms).
# 4. **Montages** of the farthest BV exemplars from THINGS centroid per category (to visually check for false alarms).

# %% [markdown]
# ## Parameters (set these before running)
#
# Adjust these to match the script's CLI options.

# %%
from pathlib import Path
from datetime import datetime
import numpy as np
import pandas as pd
from scipy import stats
from tqdm import tqdm
from PIL import Image, ImageDraw, ImageFont

SCRIPT_DIR = Path(".").resolve()  # or Path(__file__).resolve().parent when run as script

# --- Config (equivalent to argparse) ---
embedding = "clip"  # "clip" or "dinov3"
_run_id = datetime.now().strftime("%Y%m%d")
out_dir = SCRIPT_DIR / f"bv_to_things_centroid_outputs_{_run_id}"  # new folder per run for plots and CSVs
save_exemplar_csv = False
tsne_category = ["giraffe","pasta","zebra","bird","bottle","table"]  # e.g. "giraffe" for single category; None to skip
tsne_all_categories = False
tsne_perplexity = 30.0
tsne_top12_by_similarity = True  # plot only top-12 high-similarity BV exemplars per category (CLIP + SIMILARITY_CSV)
tsne_zscore = True  # z-score embeddings before t-SNE so feature scale does not dominate
rdm_top12_and_things = True  # plot RDM of BV top-12 + THINGS exemplars per category (same subset as t-SNE)
rdm_max_things = 50  # cap THINGS exemplars in RDM for readability (None = use all)
montage_farthest = False
montage_top12_by_similarity = True  # use all-frames similarity CSV to sample top 12 BV per category (CLIP only)
montage_n = 12
montage_max_categories = 0  # 0 = all
filter_threshold = 0.27  # use filtered list (merged_frame_detections_with_metadata_filtered-{threshold}.csv)
project_root = SCRIPT_DIR.parent.parent.parent  # repo root (object-detection), where frame_data/ lives
metadata_csv = project_root / f"frame_data/merged_frame_detections_with_metadata_filtered-{filter_threshold}.csv"
cropped_dir = Path("/data2/dataset/babyview/868_hours/outputs/yoloe_cdi_all_cropped_by_class")
montage_cell_size = (128, 128)
montage_cols = 4

# %%
# Original (non-grouped) per-image embeddings; only rows in filtered metadata are used
BV_EMBEDDINGS_BASE = Path("/data2/dataset/babyview/868_hours/outputs/yoloe_cdi_embeddings")
BV_ORIGINAL_EMBEDDINGS_DIRS = {
    "clip": BV_EMBEDDINGS_BASE / "clip_embeddings_new",
    "dinov3": BV_EMBEDDINGS_BASE / "facebook_dinov3-vitb16-pretrain-lvd1689m",
}
THINGS_BASE = Path("/ccn2/dataset/babyview/outputs_20250312")
THINGS_EMBEDDINGS_DIRS = {
    "clip": THINGS_BASE / "things_bv_overlapping_categories_corrected/embeddings/image_embeddings/clip_image_embeddings_npy_by_category",
    "dinov3": THINGS_BASE / "image_embeddings/things_bv_overlapping_categories_corrected/facebook_dinov3-vitb16-pretrain-lvd1689m",
}
CATEGORIES_FILE = SCRIPT_DIR / "../../../data/things_bv_overlap_categories_exclude_zero_precisions.txt"
EXCLUDED_SUBJECT = "00270001"
MIN_EXEMPLARS = 2
# All-frames CSV with image-text (or image-to-centroid) similarity per (category, embedding); used for top-12 BV montage
SIMILARITY_CSV = BV_EMBEDDINGS_BASE / "clip_image_embeddings_filtered_all_frames_exclude-people_exclude-subject-00270001.csv"

# %% [markdown]
# ## Helpers: crop dir, exemplar→crop lookup, montage

# %%
def get_category_crop_dir(cropped_dir, cat_name):
    """Return Path to category subfolder (match by name, case-insensitive)."""
    cat_lower = cat_name.strip().lower()
    direct = cropped_dir / cat_name
    if direct.exists() and direct.is_dir():
        return direct
    for p in cropped_dir.iterdir():
        if p.is_dir() and p.name.lower() == cat_lower:
            return p
    return cropped_dir / cat_name


def build_exemplar_to_crop_lookup(metadata_csv, usecols=None, chunksize=500_000):
    """Build (class_name, subject_id, age_mo) -> original_embedding_name (stem for crop)."""
    if usecols is None:
        usecols = ["class_name", "subject_id", "age_mo", "original_embedding_name"]
    lookup = {}
    for chunk in tqdm(
        pd.read_csv(metadata_csv, usecols=usecols, chunksize=chunksize,
                    dtype={"subject_id": str, "class_name": str},
                    na_values=[], keep_default_na=False),
        desc="Metadata chunks", unit="chunk",
    ):
        chunk = chunk.dropna(subset=["class_name", "subject_id", "age_mo", "original_embedding_name"])
        chunk["subject_id_norm"] = chunk["subject_id"].str.strip().str.lstrip("S")
        chunk["age_mo_int"] = pd.to_numeric(chunk["age_mo"], errors="coerce").fillna(-1).astype(int)
        chunk = chunk[chunk["age_mo_int"] >= 0]
        for _, row in chunk.iterrows():
            key = (str(row["class_name"]).strip().lower(), row["subject_id_norm"], row["age_mo_int"])
            if key not in lookup:
                stem = str(row["original_embedding_name"]).strip()
                if stem.endswith(".npy"):
                    stem = stem[:-4]
                lookup[key] = stem
    return lookup


def make_montage_with_labels(images, labels, n_cols, cell_size, label_height=24):
    """Tile PIL images into a grid and draw distance label below each cell."""
    if not images:
        return None
    n = len(images)
    n_rows = (n + n_cols - 1) // n_cols
    total_h = n_rows * (cell_size[1] + label_height)
    total_w = n_cols * cell_size[0]
    out = Image.new("RGB", (total_w, total_h), (255, 255, 255))
    draw = ImageDraw.Draw(out)
    try:
        font = ImageFont.truetype("/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf", 12)
    except Exception:
        font = ImageFont.load_default()
    for idx, img in enumerate(images):
        row, col = idx // n_cols, idx % n_cols
        if img.size != (cell_size[0], cell_size[1]):
            img = img.resize((cell_size[0], cell_size[1]), Image.Resampling.LANCZOS)
        r0 = row * (cell_size[1] + label_height)
        c0 = col * cell_size[0]
        out.paste(img, (c0, r0))
        if idx < len(labels):
            draw.text((c0 + 2, r0 + cell_size[1] + 2), f"d={labels[idx]}", fill=(0, 0, 0), font=font)
    return out

# %% [markdown]
# ## Load categories, BV embeddings, THINGS embeddings

# %%
def load_allowed_categories():
    if not CATEGORIES_FILE.exists():
        return None
    with open(CATEGORIES_FILE) as f:
        return set(line.strip() for line in f if line.strip())


def load_filtered_metadata(metadata_csv, excluded_subject=None):
    """Load filtered metadata; return DataFrame with original_embedding_name, class_name (lower), subject_id_norm, age_mo (int)."""
    df = pd.read_csv(metadata_csv, usecols=["original_embedding_name", "class_name", "subject_id", "age_mo"],
                     dtype={"subject_id": str, "class_name": str}, na_values=[], keep_default_na=False)
    df = df.dropna(subset=["original_embedding_name", "class_name"])
    df["class_name"] = df["class_name"].str.strip().str.lower()
    df["subject_id_norm"] = df["subject_id"].astype(str).str.strip().str.lstrip("S")
    df["age_mo"] = pd.to_numeric(df["age_mo"], errors="coerce").fillna(-1).astype(int)
    if excluded_subject:
        df = df[df["subject_id_norm"] != excluded_subject]
    df = df.drop_duplicates(subset=["original_embedding_name"], keep="first")
    return df


def load_bv_embeddings_from_filtered(embedding_type, metadata_csv, allowed_categories, excluded_subject, min_exemplars=2):
    """Load BV from original (non-grouped) embedding dir, only for rows in filtered metadata.
    Returns category_embeddings, category_exemplar_ids with ids = [(subject_id, age_mo, stem), ...]."""
    embeddings_dir = Path(BV_ORIGINAL_EMBEDDINGS_DIRS[embedding_type])
    if not embeddings_dir.exists():
        raise FileNotFoundError(f"BV embeddings dir not found: {embeddings_dir}")
    meta = load_filtered_metadata(metadata_csv, excluded_subject=excluded_subject)
    cat_to_rows = meta.groupby("class_name", sort=False).apply(
        lambda g: list(zip(g["original_embedding_name"], g["subject_id_norm"], g["age_mo"]))
    ).to_dict()
    category_embeddings = {}
    category_exemplar_ids = {}
    for cat_name, rows in cat_to_rows.items():
        if allowed_categories is not None and cat_name not in allowed_categories:
            continue
        embs, ids = [], []
        cat_folder = embeddings_dir / cat_name
        if not cat_folder.exists():
            for d in embeddings_dir.iterdir():
                if d.is_dir() and d.name.lower() == cat_name:
                    cat_folder = d
                    break
        for emb_name, sid, age_mo in rows:
            path = cat_folder / emb_name
            if not path.exists() and not str(emb_name).endswith(".npy"):
                path = cat_folder / f"{emb_name}.npy"
            if not path.exists():
                continue
            try:
                e = np.load(path)
                e = np.asarray(e, dtype=np.float64).flatten()
                embs.append(e)
                stem = str(emb_name).rstrip(".npy") if str(emb_name).endswith(".npy") else str(emb_name)
                ids.append((sid, age_mo, stem))
            except Exception:
                continue
        if len(embs) >= min_exemplars:
            category_embeddings[cat_name] = np.array(embs)
            category_exemplar_ids[cat_name] = ids
    return category_embeddings, category_exemplar_ids


def load_things_embeddings(embedding_type, allowed_categories, min_exemplars=2):
    from load_things_embeddings import load_things_dinov3_from_dir
    things_dir = THINGS_EMBEDDINGS_DIRS[embedding_type]
    cat_embs, _ = load_things_dinov3_from_dir(
        things_dir, allowed_categories=allowed_categories, min_exemplars=min_exemplars,
    )
    return cat_embs


def compute_things_centroids(things_embeddings):
    return {cat: X.mean(axis=0) for cat, X in things_embeddings.items()}

# %% [markdown]
# ## Compute distances and build summary

# %%
def run_distances(bv_embeddings, bv_ids, things_embeddings, things_centroids, categories_common):
    summary_rows = []
    exemplar_rows = []
    for cat in tqdm(categories_common, desc="Categories"):
        bv_X = bv_embeddings[cat]
        bv_id_list = bv_ids[cat]
        th_centroid = things_centroids[cat]

        bv_centroid = bv_X.mean(axis=0)
        dist_to_things = np.linalg.norm(bv_X - th_centroid, axis=1)
        dist_to_bv = np.linalg.norm(bv_X - bv_centroid, axis=1)

        n_bv, n_things = bv_X.shape[0], things_embeddings[cat].shape[0]
        mean_d_th = float(np.mean(dist_to_things))
        std_d_th = float(np.std(dist_to_things))
        mean_d_bv = float(np.mean(dist_to_bv))
        std_d_bv = float(np.std(dist_to_bv))
        if n_bv >= 2 and np.std(dist_to_things) > 0 and np.std(dist_to_bv) > 0:
            r, _ = stats.pearsonr(dist_to_things, dist_to_bv)
        else:
            r = np.nan
        summary_rows.append({
            "category": cat, "mean_bv_to_things_centroid": mean_d_th, "std_bv_to_things_centroid": std_d_th,
            "mean_bv_to_bv_centroid": mean_d_bv, "std_bv_to_bv_centroid": std_d_bv,
            "corr_dist_things_vs_dist_bv": r, "n_bv": n_bv, "n_things": n_things,
        })
        for i, id_entry in enumerate(bv_id_list):
            sid, age_mo = id_entry[0], id_entry[1]
            stem = id_entry[2] if len(id_entry) > 2 else None
            exemplar_rows.append({
                "category": cat, "subject_id": sid, "age_mo": age_mo,
                "dist_to_things_centroid": float(dist_to_things[i]), "dist_to_bv_centroid": float(dist_to_bv[i]),
                "stem": stem,
            })
    return summary_rows, exemplar_rows

# %% [markdown]
# ## t-SNE for one category (BV vs THINGS, colored by distance to THINGS centroid)

# %%
def plot_tsne_one_category(category, bv_X, things_X, things_centroid, dist_bv_to_things, out_path,
                           perplexity=30, random_state=42, zscore=True, title_suffix=""):
    import matplotlib.pyplot as plt
    from sklearn.manifold import TSNE

    n_bv, n_things = bv_X.shape[0], things_X.shape[0]
    X_all = np.vstack([bv_X, things_X, things_centroid.reshape(1, -1)])
    if zscore:
        mean, std = X_all.mean(axis=0), X_all.std(axis=0)
        std = np.where(std > 1e-8, std, 1.0)
        X_all = (X_all - mean) / std
    n_all = X_all.shape[0]
    perplexity = min(perplexity, max(2, (n_all - 1) // 3))
    tsne = TSNE(n_components=2, perplexity=perplexity, random_state=random_state, max_iter=1000)
    coords = tsne.fit_transform(X_all)

    bx, by = coords[:n_bv].T
    tx, ty = coords[n_bv : n_bv + n_things].T
    cx, cy = coords[-1]

    fig, ax = plt.subplots(figsize=(9, 7))
    ax.scatter(tx, ty, c="lightgray", s=25, alpha=0.7, label="THINGS exemplars", edgecolors="gray")
    sc = ax.scatter(bx, by, c=dist_bv_to_things, s=40, cmap="viridis", alpha=0.85, edgecolors="black", linewidths=0.3)
    plt.colorbar(sc, ax=ax, label="BV exemplar distance to THINGS centroid")
    ax.scatter([cx], [cy], s=400, marker="*", c="red", edgecolors="darkred", linewidths=1.5, label="THINGS centroid", zorder=5)
    ax.set_title(f"t-SNE: {category}{title_suffix} — BV (colored by dist to THINGS centroid) vs THINGS")
    ax.set_xlabel("t-SNE 1")
    ax.set_ylabel("t-SNE 2")
    ax.legend(loc="best", fontsize=9)
    ax.set_aspect("equal")
    plt.tight_layout()
    plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.close()
    print(f"  Saved t-SNE: {out_path}")

# %% [markdown]
# ## RDM: BV top-12 vs THINGS exemplars (1 - Pearson correlation)

# %%
def plot_rdm_one_category(category, bv_X, things_X, out_path, title_suffix="", max_things=None, random_state=42):
    """Plot RDM (1 - Pearson correlation) for [BV exemplars | THINGS exemplars]."""
    import matplotlib.pyplot as plt

    n_bv, n_things = bv_X.shape[0], things_X.shape[0]
    if max_things is not None and n_things > max_things:
        rng = np.random.default_rng(random_state)
        idx = rng.choice(n_things, size=max_things, replace=False)
        things_X = things_X[idx]
        n_things = max_things
    X = np.vstack([bv_X, things_X])
    n = X.shape[0]
    corr = np.corrcoef(X)
    rdm = 1.0 - np.nan_to_num(corr, nan=0.0, posinf=0.0, neginf=2.0)
    np.fill_diagonal(rdm, 0)

    fig, ax = plt.subplots(figsize=(8, 7))
    im = ax.imshow(rdm, cmap="viridis", aspect="equal", vmin=0, vmax=2)
    ax.axvline(n_bv - 0.5, color="white", linewidth=1.5)
    ax.axhline(n_bv - 0.5, color="white", linewidth=1.5)
    ax.set_xticks([n_bv // 2 - 0.5, n_bv + (n_things - 1) // 2])
    ax.set_xticklabels(["BV (top-12)", "THINGS"])
    ax.set_yticks([n_bv // 2 - 0.5, n_bv + (n_things - 1) // 2])
    ax.set_yticklabels(["BV (top-12)", "THINGS"])
    ax.set_title(f"RDM: {category}{title_suffix} — 1 - correlation (BV vs THINGS)")
    plt.colorbar(im, ax=ax, label="Dissimilarity (1 - r)")
    plt.tight_layout()
    plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.close()
    print(f"  Saved RDM: {out_path}")

# %%
def plot_rdm_all_categories(bv_means, th_means, category_names, out_path):
    """Plot one RDM: rows/cols = [BV_avg_cat1, ..., BV_avg_catN, THINGS_avg_cat1, ..., THINGS_avg_catN].
    bv_means, th_means: (N, dim). Dissimilarity = 1 - Pearson r."""
    import matplotlib.pyplot as plt

    N = len(category_names)
    X = np.vstack([np.asarray(bv_means), np.asarray(th_means)])
    corr = np.corrcoef(X)
    rdm = 1.0 - np.nan_to_num(corr, nan=0.0, posinf=0.0, neginf=2.0)
    np.fill_diagonal(rdm, 0)

    fig, ax = plt.subplots(figsize=(max(8, N * 0.5), max(7, N * 0.45)))
    im = ax.imshow(rdm, cmap="viridis", aspect="equal", vmin=0, vmax=2)
    ax.axvline(N - 0.5, color="white", linewidth=1.5)
    ax.axhline(N - 0.5, color="white", linewidth=1.5)
    ticks = list(range(N)) + list(range(N, 2 * N))
    labels = [f"{c} (BV)" for c in category_names] + [f"{c} (TH)" for c in category_names]
    ax.set_xticks(ticks)
    ax.set_yticks(ticks)
    ax.set_xticklabels(labels, rotation=90, ha="right", fontsize=8)
    ax.set_yticklabels(labels, fontsize=8)
    ax.set_title("RDM: all selected categories — BV avg (top-12) vs THINGS avg (1 - r)")
    plt.colorbar(im, ax=ax, label="Dissimilarity (1 - r)")
    plt.tight_layout()
    plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.close()
    print(f"  Saved RDM (all categories): {out_path}")

# %% [markdown]
# ## Run pipeline: load data, compute distances, save outputs

# %%
out_dir = Path(out_dir)
out_dir.mkdir(parents=True, exist_ok=True)
prefix = f"bv_to_things_centroid_{embedding}"

allowed = load_allowed_categories()
print(f"Using {len(allowed) if allowed else 'all'} categories")

print("Loading BV embeddings (from filtered list, original embeddings)...")
bv_embeddings, bv_ids = load_bv_embeddings_from_filtered(
    embedding, metadata_csv, allowed, EXCLUDED_SUBJECT, MIN_EXEMPLARS
)
print("Loading THINGS embeddings...")
things_embeddings = load_things_embeddings(embedding, allowed, MIN_EXEMPLARS)
categories_common = sorted(set(bv_embeddings.keys()) & set(things_embeddings.keys()))
print(f"Common categories: {len(categories_common)}")

things_centroids = compute_things_centroids(things_embeddings)
summary_rows, exemplar_rows = run_distances(
    bv_embeddings, bv_ids, things_embeddings, things_centroids, categories_common
)
summary_df = pd.DataFrame(summary_rows)
summary_df = summary_df.sort_values("mean_bv_to_things_centroid", ascending=False).reset_index(drop=True)
summary_path = out_dir / f"{prefix}_summary.csv"
summary_df.to_csv(summary_path, index=False)
print(f"Saved summary: {summary_path}")
# Out:
# Using 163 categories
# Loading BV embeddings (from filtered list, original embeddings)...
# /tmp/ipykernel_3986875/273446095.py:29: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   cat_to_rows = meta.groupby("class_name", sort=False).apply(
# Loading THINGS embeddings...
# Common categories: 162
# Categories: 100%|██████████| 162/162 [00:08<00:00, 18.86it/s]
# Saved summary: /home/j7yang/babyview-projects/vss2026/object-detection/analysis/manuscript-2026/exemplar_variability_analyses/bv_to_things_centroid_outputs_20260304/bv_to_things_centroid_clip_summary.csv

# %% [markdown]
# ## Scatter: BV spread vs distance to THINGS centroid

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(7, 6))
ax.scatter(summary_df["mean_bv_to_bv_centroid"], summary_df["mean_bv_to_things_centroid"], alpha=0.7, s=25)
ax.set_xlabel("Mean BV exemplar distance to BV centroid (within-category spread)")
ax.set_ylabel("Mean BV exemplar distance to THINGS centroid")
ax.set_title(f"BV spread vs distance to THINGS centroid ({embedding})")
lims = [min(ax.get_xlim()[0], ax.get_ylim()[0]), max(ax.get_xlim()[1], ax.get_ylim()[1])]
ax.plot(lims, lims, "k--", alpha=0.5, label="y=x")
ax.legend()
ax.set_aspect("equal")
plt.tight_layout()
scatter_path = out_dir / f"{prefix}_spread_vs_things_centroid.png"
plt.savefig(scatter_path, dpi=150, bbox_inches="tight")
plt.close()
print(f"Saved scatter: {scatter_path}")
# Out:
# Saved scatter: /home/j7yang/babyview-projects/vss2026/object-detection/analysis/manuscript-2026/exemplar_variability_analyses/bv_to_things_centroid_outputs_20260304/bv_to_things_centroid_clip_spread_vs_things_centroid.png

# %% [markdown]
# ## Optional: save per-exemplar CSV

# %%
if save_exemplar_csv:
    exemplar_df = pd.DataFrame(exemplar_rows)
    exemplar_path = out_dir / f"{prefix}_per_exemplar.csv"
    exemplar_df.to_csv(exemplar_path, index=False)
    print(f"Saved per-exemplar: {exemplar_path}")

# %% [markdown]
# ## Optional: t-SNE for one or all categories

# %%
if tsne_all_categories or tsne_category:
    tsne_dir = out_dir / f"{prefix}_tsne_by_category"
    tsne_dir.mkdir(exist_ok=True)
    rdm_dir = out_dir / f"{prefix}_rdm_by_category" if rdm_top12_and_things else None
    if rdm_dir is not None:
        rdm_dir.mkdir(exist_ok=True)
    if tsne_all_categories:
        categories_to_plot = categories_common
        print(f"Running t-SNE for all {len(categories_to_plot)} categories...")
    else:
        # tsne_category can be a single string or a list of category names
        requested = [tsne_category] if isinstance(tsne_category, str) else list(tsne_category)
        categories_to_plot = []
        for cat in requested:
            c = str(cat).strip().lower()
            match = next((x for x in categories_common if x.lower() == c), None)
            if match:
                categories_to_plot.append(match)
        print(f"Running t-SNE for {len(categories_to_plot)} categories: {categories_to_plot}")
    tsne_top12_stems = {}
    if tsne_top12_by_similarity and embedding == "clip" and SIMILARITY_CSV.exists():
        sim_df = pd.read_csv(SIMILARITY_CSV)
        sim_col = next((c for c in ["cosine_similarity", "similarity", "sim", "cos_sim"] if c in sim_df.columns), None)
        cat_col = next((c for c in ["class_name", "category", "cat"] if c in sim_df.columns), None)
        emb_col = next((c for c in ["original_embedding_name", "embedding_name", "embedding_id", "embedding"] if c in sim_df.columns), None)
        if "frame_path" in sim_df.columns and (cat_col is None or emb_col is None):
            sim_df["embedding_name"] = sim_df["frame_path"].apply(lambda p: Path(p).name)
            sim_df["embedding_name"] = sim_df["embedding_name"].apply(lambda x: x if str(x).endswith(".npy") else f"{x}.npy")
            sim_df["class_name"] = sim_df["frame_path"].apply(lambda p: Path(p).parent.name).str.strip().str.lower()
        if sim_col is not None:
            sim_df["sim_value"] = pd.to_numeric(sim_df[sim_col], errors="coerce")
            if "class_name" not in sim_df.columns and cat_col:
                sim_df["class_name"] = sim_df[cat_col].astype(str).str.strip().str.lower()
            if "embedding_name" not in sim_df.columns and emb_col:
                sim_df["embedding_name"] = sim_df[emb_col].astype(str).str.strip()
                sim_df["embedding_name"] = sim_df["embedding_name"].apply(lambda x: x if x.endswith(".npy") else f"{x}.npy")
            meta = load_filtered_metadata(metadata_csv, excluded_subject=EXCLUDED_SUBJECT)
            meta["original_embedding_name"] = meta["original_embedding_name"].astype(str).str.strip()
            meta["original_embedding_name"] = meta["original_embedding_name"].apply(lambda x: x if x.endswith(".npy") else f"{x}.npy")
            filtered_set = set(zip(meta["class_name"].values, meta["original_embedding_name"].values))
            for cat in categories_to_plot:
                cat_sim = sim_df[sim_df["class_name"] == cat].dropna(subset=["sim_value"])
                cat_sim = cat_sim[cat_sim.apply(lambda r: (r["class_name"], r["embedding_name"]) in filtered_set, axis=1)]
                top12 = cat_sim.nlargest(12, "sim_value")
                tsne_top12_stems[cat] = [str(r["embedding_name"]).rstrip(".npy") for _, r in top12.iterrows()]
    rdm_bv_means, rdm_th_means, rdm_cat_names = [], [], []
    for match in tqdm(categories_to_plot, desc="t-SNE"):
        bv_X = bv_embeddings[match]
        th_X = things_embeddings[match]
        th_centroid = things_centroids[match]
        dist_bv = np.linalg.norm(bv_X - th_centroid, axis=1)
        out_name = f"tsne_{match}.png"
        if tsne_top12_stems and match in tsne_top12_stems:
            stems_want = tsne_top12_stems[match]
            bv_id_list = bv_ids[match]
            stem_to_idx = {str(id_entry[2]): i for i, id_entry in enumerate(bv_id_list)}
            indices = [stem_to_idx[s] for s in stems_want if s in stem_to_idx]
            if len(indices) >= 2:
                bv_X = bv_X[indices]
                dist_bv = dist_bv[indices]
                out_name = f"tsne_{match}_top12.png"
        title_suffix = " (top-12 by similarity)" if "_top12" in out_name else ""
        plot_tsne_one_category(match, bv_X, th_X, th_centroid, dist_bv,
                              tsne_dir / out_name, perplexity=tsne_perplexity, zscore=tsne_zscore, title_suffix=title_suffix)
        if rdm_dir is not None:
            rdm_name = f"rdm_{match}_top12.png" if "_top12" in out_name else f"rdm_{match}.png"
            plot_rdm_one_category(match, bv_X, th_X, rdm_dir / rdm_name, title_suffix=title_suffix, max_things=rdm_max_things)
            rdm_bv_means.append(bv_X.mean(axis=0))
            rdm_th_means.append(th_centroid)
            rdm_cat_names.append(match)
    if rdm_dir is not None and len(rdm_bv_means) > 0:
        plot_rdm_all_categories(rdm_bv_means, rdm_th_means, rdm_cat_names, rdm_dir / "rdm_all_categories_top12.png")
# Out:
# Running t-SNE for 6 categories: ['giraffe', 'pasta', 'zebra', 'bird', 'bottle', 'table']
# t-SNE:  17%|█▋        | 1/6 [00:00<00:04,  1.24it/s]
#   Saved t-SNE: /home/j7yang/babyview-projects/vss2026/object-detection/analysis/manuscript-2026/exemplar_variability_analyses/bv_to_things_centroid_outputs_20260304/bv_to_things_centroid_clip_tsne_by_category/tsne_giraffe_top12.png
#   Saved RDM: /home/j7yang/babyview-projects/vss2026/object-detection/analysis/manuscript-2026/exemplar_variability_analyses/bv_to_things_centroid_outputs_20260304/bv_to_things_centroid_clip_rdm_by_category/rdm_giraffe_top12.png
# t-SNE:  33%|███▎      | 2/6 [00:01<00:02,  1.38it/s]
#   Saved t-SNE: /home/j7yang/babyview-projects/vss2026/object-detection/analysis/manuscript-2026/exemplar_variability_analyses/bv_to_things_centroid_outputs_20260304/bv_to_things_centroid_clip_tsne_by_category/tsne_pasta_top12.png
# ...

# %% [markdown]
# ## Optional: Montages — top 12 BV by similarity (from all-frames CSV) or farthest from THINGS centroid

# %%
do_montage = (montage_farthest or montage_top12_by_similarity) and metadata_csv.exists() and cropped_dir.exists()
use_top12_similarity = montage_top12_by_similarity and embedding == "clip" and SIMILARITY_CSV.exists()
if do_montage and use_top12_similarity:
    # Sample top 12 BV per category from all-frames similarity CSV (BV embedding base)
    sim_df = pd.read_csv(SIMILARITY_CSV)
    sim_col = next((c for c in ["cosine_similarity", "similarity", "sim", "cos_sim"] if c in sim_df.columns), None)
    cat_col = next((c for c in ["class_name", "category", "cat"] if c in sim_df.columns), None)
    emb_col = next((c for c in ["original_embedding_name", "embedding_name", "embedding_id", "embedding"] if c in sim_df.columns), None)
    # If CSV has only frame_path + similarity, derive category and embedding name from path (e.g. .../clip_embeddings_new/airplane/airplane_*.npy)
    if "frame_path" in sim_df.columns and (cat_col is None or emb_col is None):
        sim_df["embedding_name"] = sim_df["frame_path"].apply(lambda p: Path(p).name)
        sim_df["embedding_name"] = sim_df["embedding_name"].apply(lambda x: x if str(x).endswith(".npy") else f"{x}.npy")
        sim_df["class_name"] = sim_df["frame_path"].apply(lambda p: Path(p).parent.name).str.strip().str.lower()
        cat_col = "class_name"
        emb_col = "embedding_name"
    if sim_col is None or cat_col is None or emb_col is None:
        raise ValueError(f"Similarity CSV must have similarity and (category + embedding-id) or frame_path. Found: {list(sim_df.columns)}")
    if "class_name" not in sim_df.columns:
        sim_df["class_name"] = sim_df[cat_col].astype(str).str.strip().str.lower()
    if "embedding_name" not in sim_df.columns:
        sim_df["embedding_name"] = sim_df[emb_col].astype(str).str.strip()
        sim_df["embedding_name"] = sim_df["embedding_name"].apply(lambda x: x if x.endswith(".npy") else f"{x}.npy")
    sim_df["sim_value"] = pd.to_numeric(sim_df[sim_col], errors="coerce")
    meta = load_filtered_metadata(metadata_csv, excluded_subject=EXCLUDED_SUBJECT)
    meta["original_embedding_name"] = meta["original_embedding_name"].astype(str).str.strip()
    meta["original_embedding_name"] = meta["original_embedding_name"].apply(lambda x: x if x.endswith(".npy") else f"{x}.npy")
    filtered_set = set(zip(meta["class_name"].values, meta["original_embedding_name"].values))
    meta_key = meta.set_index(["class_name", "original_embedding_name"]).sort_index()
    montage_dir = out_dir / f"{prefix}_montages_top12_by_similarity"
    montage_dir.mkdir(exist_ok=True)
    cell_size = montage_cell_size
    cats_for_montage = categories_common
    if montage_max_categories > 0:
        top_cats = summary_df.head(montage_max_categories)["category"].tolist()
        cats_for_montage = [c for c in categories_common if c in top_cats]
    for cat in tqdm(cats_for_montage, desc="Montages (top 12 by similarity)"):
        cat_sim = sim_df[sim_df["class_name"] == cat].dropna(subset=["sim_value"])
        cat_sim = cat_sim[cat_sim.apply(lambda r: (r["class_name"], r["embedding_name"]) in filtered_set, axis=1)]
        top12 = cat_sim.nlargest(montage_n, "sim_value")
        if len(top12) == 0:
            continue
        images, labels = [], []
        cat_dir = get_category_crop_dir(cropped_dir, cat)
        for _, row in top12.iterrows():
            key = (row["class_name"], row["embedding_name"])
            if key not in meta_key.index:
                continue
            sid = str(meta_key.loc[key, "subject_id_norm"])
            age_mo = int(meta_key.loc[key, "age_mo"])
            stem = str(row["embedding_name"]).rstrip(".npy")
            crop_path = None
            for ext in (".jpg", ".jpeg", ".png"):
                p = cat_dir / f"{stem}{ext}"
                if p.exists():
                    crop_path = p
                    break
            if crop_path is None:
                continue
            try:
                img = Image.open(crop_path).convert("RGB")
                images.append(img)
                labels.append(f"{row['sim_value']:.2f}")
            except Exception:
                continue
        if not images:
            continue
        n_cols_use = min(montage_cols, len(images))
        montage = make_montage_with_labels(images, labels, n_cols_use, cell_size)
        if montage is not None:
            out_path = montage_dir / f"top12_by_similarity_{cat}.png"
            montage.save(out_path)
            with open(montage_dir / f"top12_by_similarity_{cat}_similarities.txt", "w") as f:
                f.write("similarity (left-to-right, top-to-bottom)\n")
                f.write("\n".join(labels))
    print(f"Saved top-12-by-similarity montages to {montage_dir}")
elif do_montage and montage_farthest:
    exemplar_df = pd.DataFrame(exemplar_rows)
    montage_dir = out_dir / f"{prefix}_montages_farthest_from_things_centroid"
    montage_dir.mkdir(exist_ok=True)
    cell_size = montage_cell_size
    print("Building exemplar -> crop lookup from metadata...")
    lookup = build_exemplar_to_crop_lookup(metadata_csv)
    cats_for_montage = categories_common
    if montage_max_categories > 0:
        top_cats = summary_df.head(montage_max_categories)["category"].tolist()
        cats_for_montage = [c for c in categories_common if c in top_cats]
    for cat in tqdm(cats_for_montage, desc="Montages (farthest from THINGS centroid)"):
        rows = exemplar_df[exemplar_df["category"] == cat].copy()
        rows = rows.sort_values("dist_to_things_centroid", ascending=False).reset_index(drop=True)
        n_show = min(montage_n, len(rows))
        rows = rows.head(n_show)
        cat_key_lower = cat.strip().lower()
        images, labels = [], []
        for _, row in rows.iterrows():
            sid, age_mo = row["subject_id"], int(row["age_mo"])
            stem = row.get("stem") if pd.notna(row.get("stem")) and row.get("stem") else None
            if stem is None:
                key = (cat_key_lower, sid, age_mo)
                stem = lookup.get(key) or lookup.get((cat, sid, age_mo))
            if stem is None:
                continue
            cat_dir = get_category_crop_dir(cropped_dir, cat)
            crop_path = None
            for ext in (".jpg", ".jpeg", ".png"):
                p = cat_dir / f"{stem}{ext}"
                if p.exists():
                    crop_path = p
                    break
            if crop_path is None:
                continue
            try:
                img = Image.open(crop_path).convert("RGB")
                images.append(img)
                labels.append(f"{row['dist_to_things_centroid']:.1f}")
            except Exception:
                continue
        if not images:
            continue
        n_cols_use = min(montage_cols, len(images))
        montage = make_montage_with_labels(images, labels, n_cols_use, cell_size)
        if montage is not None:
            out_path = montage_dir / f"farthest_from_things_centroid_{cat}.png"
            montage.save(out_path)
            with open(montage_dir / f"farthest_from_things_centroid_{cat}_distances.txt", "w") as f:
                f.write("dist_to_THINGS_centroid (left-to-right, top-to-bottom)\n")
                f.write("\n".join(labels))
    print(f"Saved farthest-from-THINGS-centroid montages to {montage_dir}")
elif montage_farthest or montage_top12_by_similarity:
    print("Skipping montages: metadata_csv or cropped_dir not found, or (top12_by_similarity requires embedding=clip and SIMILARITY_CSV to exist).")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /data/j7yang/anaconda3/envs/vislearnlabpy/lib/python3.12/pathlib.py:555, in PurePath.drive(self)
#     554 try:
# --> 555     return self._drv
#     556 except AttributeError:
#
# AttributeError: 'PosixPath' object has no attribute '_drv'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79], line 13
#      11 sim_df["embedding_name"] = sim_df["frame_path"].apply(lambda p: Path(p).name)
#      12 sim_df["embedding_name"] = sim_df["embedding_name"].apply(lambda x: x if str(x).endswith(".npy") else f"{x}.npy")
# ---> 13 sim_df["class_name"] = sim_df["frame_path"].apply(lambda p: Path(p).parent.name).str.strip().str.lower()
#      14 cat_col = "class_name"
#      15 emb_col = "embedding_name"
#
# ...
